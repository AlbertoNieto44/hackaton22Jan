# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns' ,100)
pd.set_option('display.max_rows' ,200)

# %%
time = pd.read_pickle("Time.pkl")
aircraft = pd.read_pickle("Aircraft.pkl")
assessments = pd.read_pickle("Assessments.pkl")
component = pd.read_pickle("Component.pkl")
events = pd.read_pickle("Events.pkl")
place = pd.read_pickle("Place.pkl")
text = pd.read_pickle("Text.pkl")

# %%
time.columns
# Out:
# Index(['ITEM_ID', 'ENUMERATOR', 'Date', 'Date display_value',
#        'Local Time Of Day', 'Local Time Of Day display_value'],
#       dtype='object')

# %%
aircraft
# Out:
#         ITEM_ID  ENUMERATOR ATC / Advisory.CTAF  \
# 0         75085           1
# 1         79866           1
# 202549    79866           2
# 2         79912           1
# 3         79965           1
# ...         ...         ...                 ...
# 202544  1654792           1
# 202545  1654892           1
# 202546  1655351           1
# 202547  1655360           1
# 202548  1655584           1
#
#        ATC / Advisory.CTAF display_value ATC / Advisory.Center  \
# 0                                    NaN
# 1                                    NaN                   ZID
# 202549                               NaN
# 2                                    NaN
# 3                                    NaN
# ...                                  ...                   ...
# 202544                               NaN
# 202545                               NaN
# 202546                               NaN
# 202547                               NaN
# 202548                               NaN
#
# ...

# %%
aircraft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 251719 entries, 0 to 202548
# Data columns (total 72 columns):
# ITEM_ID                                               251719 non-null int64
# ENUMERATOR                                            251719 non-null int64
# ATC / Advisory.CTAF                                   251719 non-null object
# ATC / Advisory.CTAF display_value                     2818 non-null object
# ATC / Advisory.Center                                 251719 non-null object
# ATC / Advisory.Center display_value                   13299 non-null object
# ATC / Advisory.FSS                                    251719 non-null object
# ATC / Advisory.Ground                                 251719 non-null object
# ATC / Advisory.Military Facility                      251719 non-null object
# ATC / Advisory.Ramp                                   251719 non-null object
# ATC / Advisory.TRACON                                 251719 non-null object
# ...

# %%
assessments
# Out:
#         ITEM_ID  ENUMERATOR         Contributing Factors / Situations  \
# 0         75085           1
# 1         79866           1
# 2         79912           1
# 3         79965           1
# 4         79997           1
# ...         ...         ...                                       ...
# 197148  1654792           1                                 Procedure
# 197149  1654892           1         Environment - Non Weather Related
# 197150  1655351           1                                  Aircraft
# 197151  1655360           1                                  Aircraft
# 197152  1655584           1  ATC Equipment / Nav Facility / Buildings
#
#        Contributing Factors / Situations display_value  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# ...

# %%
component
# Out:
#        ITEM_ID  ENUMERATOR                     Aircraft Component  \
# 0       257406           1                                 HF SSB
# 1       258039           1                                    ADF
# 60473   258039           2  Navigational Equipment and Processing
# 68994   258039           3                            Transponder
# 2       258065           1                          TCAS Software
# ...        ...         ...                                    ...
# 60468  1654078           1       GPS & Other Satellite Navigation
# 60469  1654079           1       GPS & Other Satellite Navigation
# 60470  1654400           1                             DC Battery
# 60471  1654559           1                      Fuel Booster Pump
# 60472  1654609           1       GPS & Other Satellite Navigation
#
#                 Aircraft Component display_value Aircraft Reference  \
# 0                                            NaN                  X
# ...

# %%
events
# Out:
#         ITEM_ID  ENUMERATOR Anomaly.ATC Issue Anomaly.ATC Issue display_value  \
# 0         75085           1                                               NaN
# 1         79866           1                                               NaN
# 2         79912           1                                               NaN
# 3         79965           1                                               NaN
# 4         79997           1                                               NaN
# ...         ...         ...               ...                             ...
# 204321  1654792           1                                               NaN
# 204322  1654892           1                                               NaN
# 204323  1655351           1                                               NaN
# 204324  1655360           1                                               NaN
# 204325  1655584           1                                               NaN
#
# ...

# %%
place
# Out:
#         ITEM_ID  ENUMERATOR Altitude.AGL.Single Value  \
# 0         75085           1
# 1         79866           1
# 2         79912           1
# 3         79965           1
# 4         79997           1                         0
# ...         ...         ...                       ...
# 203505  1654792           1                         0
# 203506  1654892           1                         0
# 203507  1655351           1
# 203508  1655360           1
# 203509  1655584           1
#
#        Altitude.AGL.Single Value display_value Altitude.MSL.Single Value  \
# 0                                          NaN                      1500
# 1                                          NaN                     31000
# 2                                          NaN                       900
# 3                                          NaN                      7500
# 4                                            0
# ...                                        ...                       ...
# ...

# %%
text
